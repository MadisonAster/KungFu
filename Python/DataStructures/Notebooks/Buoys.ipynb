# %%
# %matplotlib inline
from ipywidgets import interactive, fixed

# %% [markdown]
# **Hello Markdown**

# %%
from lorenz import solve_lorenz
w=interactive(solve_lorenz,sigma=(0.0,50.0),rho=(0.0,50.0))
w
# Out:
# interactive(children=(FloatSlider(value=10.0, description='sigma', max=50.0), FloatSlider(value=2.666666666666…

# %%
import static_frame

# %%
from static_frame.performance import pydata_2018

# %%
SampleData = pydata_2018.SampleData()

# %%
pydata_2018.SampleData.FP_CSV = 'W:/Portfolio/KungFu/Python/DataStructures/Notebooks/examples/sf_pydata_2018.csv'

# %%
frame = SampleData.get('sf.FrameFloat')

# %%
print(frame)
# Out:
# <Frame>
# <Index> abcd                abce                 abcf                 abcg                 abch                ... afho                 afhp                 afhq                 afhr                 afhs                <<U4>
# <Index>                                                                                                        ...
# abcd    0.9189379786337286  0.8892108337994953   0.5204265816996025   0.5789370000448575   0.8254807573501635  ... 0.30523682136561736  0.37150039765136444  0.8468345755666938   0.7546301298940438   0.8765259752201703
# abce    0.4277213148322845  0.07880365497598152  0.7497009039833081   0.5219116176293681   0.4279913153549525  ... 0.5388547819381773   0.35839704419041996  0.4438973901099199   0.9793662501668398   0.9573040471444189
# ...
